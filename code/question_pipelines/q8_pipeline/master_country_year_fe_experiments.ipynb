# %%
# Perform PCA-based latent factor extraction on Q8 sentence embeddings,
# merge with country-year proportions, and compute temporal correlations
# between each latent factor and year to identify longitudinal semantic trends.

# %run q8_latent_factors_year_correlation.py
# Out:
# Computing embeddings for sentences...
# Batches:   0%|          | 0/5 [00:00<?, ?it/s]
# Correlation of latent_factor_1 with year: -0.056
# Correlation of latent_factor_2 with year: -0.092
# Correlation of latent_factor_3 with year: -0.327
# Correlation of latent_factor_4 with year: 0.008
# Correlation of latent_factor_5 with year: -0.118
# Correlation of latent_factor_6 with year: -0.014
# Correlation of latent_factor_7 with year: -0.190
# Correlation of latent_factor_8 with year: 0.012
# Correlation of latent_factor_9 with year: 0.109
# Correlation of latent_factor_10 with year: 0.065

# %%
# Analyze longitudinal semantic change in Q8 sentences via PCA-derived latent factors.
# Regress latent dimensions on country and year fixed effects to isolate residual trends.
# Correlate residual latent dynamics with inter-annual semantic shift measured by cosine distance.

# %run q8_semantic_shift_latent_factors.py
# Out:
# Computing embeddings for sentences...
# Batches:   0%|          | 0/5 [00:00<?, ?it/s]
# Correlation between residual latent_factor_6 and mean semantic shift: 0.456
# Correlation between residual latent_factor_9 and mean semantic shift: -0.201

# %%
# Extract and analyze dominant semantic themes linked to PCA-derived latent factors for Q8 sentences.
# Identify top contributing sentences, derive representative keyphrases using KeyBERT, and compute yearly theme prevalence.
# Visualize temporal dynamics of latent semantic structures across country-year contexts.

# %run q8_latent_factor_theme_analysis.py
# Out:
# Computing sentence embeddings...
# Batches:   0%|          | 0/5 [00:00<?, ?it/s]
# Themes for high latent_factor_6 sentences:
# - kashmir right self determination (0.711)
# - community people kashmir right (0.617)
# - clear self determination peoples (0.606)
# - people kashmir right self (0.601)
# - self determination peoples (0.598)
# - self reliant india movement (0.596)
# - self determination peoples manipulated (0.578)
# - right self determination communities (0.571)
# - people kashmir right (0.570)
# - kashmir struggled right self (0.570)
# Themes for high latent_factor_9 sentences:
# - political courage conceive freedom (0.567)
# - self determination peoples (0.558)
# - clear self determination peoples (0.549)
# - self determination ensure future (0.541)
# - political courage conceive (0.538)
# - autonomy economic empowerment indigenous (0.533)
# - self determination peoples manipulated (0.530)
# - considerable political courage conceive (0.529)
# - determination peoples manipulated free (0.526)
# - decide future free democratic (0.524)

# %%
# Estimate and visualize country- and year-adjusted proportions of Q8_1 sentences using fixed-effects regression.
# Apply OLS with categorical controls for country and year to obtain adjusted proportions.
# Plot fitted values as a scatter visualization across country-year combinations.

# %run q8_fixed_effects_proportion.py
