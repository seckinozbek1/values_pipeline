# %%
# Perform PCA-based latent factor extraction on Q69 sentence embeddings,
# merge with country-year proportions, and compute temporal correlations
# between each latent factor and year to identify longitudinal semantic trends.

# %run q69_latent_factors_year_correlation.py
# Out:
# Computing embeddings for sentences...
# Batches:   0%|          | 0/24 [00:00<?, ?it/s]
# Correlation of latent_factor_1 with year: 0.071
# Correlation of latent_factor_2 with year: -0.110
# Correlation of latent_factor_3 with year: -0.222
# Correlation of latent_factor_4 with year: -0.117
# Correlation of latent_factor_5 with year: 0.036
# Correlation of latent_factor_6 with year: 0.060
# Correlation of latent_factor_7 with year: 0.078
# Correlation of latent_factor_8 with year: 0.107
# Correlation of latent_factor_9 with year: 0.114
# Correlation of latent_factor_10 with year: 0.008
# Correlation of latent_factor_11 with year: -0.004
# Correlation of latent_factor_12 with year: 0.223
# Correlation of latent_factor_13 with year: 0.026
# Correlation of latent_factor_14 with year: 0.041
# Correlation of latent_factor_15 with year: -0.019
# Correlation of latent_factor_16 with year: 0.115
# Correlation of latent_factor_17 with year: -0.025
# ...

# %%
# Analyze longitudinal semantic change in Q69 sentences via PCA-derived latent factors.
# Regress latent dimensions on country and year fixed effects to isolate residual trends.
# Correlate residual latent dynamics with inter-annual semantic shift measured by cosine distance.

# %run q69_semantic_shift_latent_factors.py
# Out:
# Computing embeddings for sentences...
# Batches:   0%|          | 0/24 [00:00<?, ?it/s]
# Correlation between residual latent_factor_12 and mean semantic shift: 0.533

# %%
# Extract and analyze dominant semantic themes linked to PCA-derived latent factors for Q69 sentences.
# Identify top contributing sentences, derive representative keyphrases using KeyBERT, and compute yearly theme prevalence.
# Visualize temporal dynamics of latent semantic structures across country-year contexts.

# %run q69_latent_factor_theme_analysis.py
# Out:
# Computing sentence embeddings...
# Batches:   0%|          | 0/24 [00:00<?, ?it/s]
# Themes for high latent_factor_12 sentences:
# - peacekeeping faces today (0.730)
# - new unsupported principles peacekeepers (0.726)
# - hails united nations peacekeeping (0.717)
# - commitments united nations peacekeeping (0.715)
# - contribution united nations peacekeeping (0.708)
# - challenges peacekeeping faces today (0.708)
# - tackle challenges peacekeeping faces (0.706)
# - united nations peacekeepers (0.706)
# - world challenges peacekeepers face (0.703)
# - global peacekeeping reflection (0.702)

# %%
# Estimate and visualize country- and year-adjusted proportions of Q69_1 sentences using fixed-effects regression.
# Apply OLS with categorical controls for country and year to obtain adjusted proportions.
# Plot fitted values as a scatter visualization across country-year combinations.

# %run q69_fixed_effects_proportion.py
